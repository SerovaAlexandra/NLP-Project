# %%
import pandas as pd

# %%
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
from nltk.tokenize import word_tokenize

# %%
data = []

# %%
def tag_handler(pos_tag):
    if pos_tag != None:
        if pos_tag.startswith('ADJ'):
            pos_tag = 'ADJ'
            return pos_tag
        elif pos_tag == 'INFN':
            pos_tag = 'VERB'
            return pos_tag
        elif pos_tag.startswith ('PRT'):
            pos_tag = 'PRT'
            return pos_tag
        else:
            return pos_tag
    else:
        return "None"

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)


segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
with open ('bivshaja_starosta_griffindora.txt', encoding='utf-8') as f1:
    text = f1.read()
doc1 = Doc (text)

# %%
doc1.segment(segmenter)
for elem1 in doc1.sents:
    sent_data_text1 = {}
    lemma_tag_data = []
    sent_text = elem1.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text1['sent_text'] = sent_text
    sent_data_text1 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text1 ['link'] = 'https://ficbook.net/readfic/4678689'
    sent_data_text1 ['author'] = 'Шион Недзуми'
    sent_data_text1 ['name'] = 'Бывшая староста Гриффиндора'
    data.append(sent_data_text1)

# %%
with open ('bordovij_s_zolotom.txt', encoding='utf-8') as f2:
    text2 = f2.read()
doc2 = Doc (text2)
doc2.segment(segmenter)
for elem2 in doc2.sents:
    sent_data_text2 = {}
    lemma_tag_data = []
    sent_text = elem2.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text2['sent_text'] = sent_text
    sent_data_text2 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text2 ['link'] = 'https://ficbook.net/readfic/6681775'
    sent_data_text2 ['author'] = 'Feena Fhortan'
    sent_data_text2 ['name'] = 'Бордовый с золотом, зелёный с серебром'
    data.append(sent_data_text2)

# %%
with open ('drazhe_so_vkusom.txt', encoding='utf-8') as f3:
    text3 = f3.read()
doc3 = Doc (text3)
doc3.segment(segmenter)
for elem3 in doc3.sents:
    sent_data_text3 = {}
    lemma_tag_data = []
    sent_text = elem3.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text3['sent_text'] = sent_text
    sent_data_text3 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text3 ['link'] = 'https://ficbook.net/readfic/2198686'
    sent_data_text3 ['author'] = 'Pancake M.D.'
    sent_data_text3 ['name'] = 'Драже со вкусом Поцелуй Гарри Поттера'
    data.append(sent_data_text3)

# %%
with open ('k_chemu_privodjat.txt', encoding='utf-8') as f4:
    text4 = f4.read()
doc4 = Doc (text4)
doc4.segment(segmenter)
for elem4 in doc4.sents:
    sent_data_text4 = {}
    lemma_tag_data = []
    sent_text = elem4.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text4['sent_text'] = sent_text
    sent_data_text4 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text4 ['link'] = 'https://ficbook.net/readfic/4832476'
    sent_data_text4 ['author'] = 'Kolumnist'
    sent_data_text4 ['name'] = 'К чему приводят разговоры в комнате Грейнджер'
    data.append(sent_data_text4)

# %%
with open ('na_stekle.txt', encoding='utf-8') as f5:
    text5 = f5.read()
doc5 = Doc (text5)
doc5.segment(segmenter)
for elem5 in doc5.sents:
    sent_data_text5 = {}
    lemma_tag_data = []
    sent_text = elem5.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text5['sent_text'] = sent_text
    sent_data_text5 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text5 ['link'] = 'https://ficbook.net/readfic/2279447'
    sent_data_text5 ['author'] = 'Чацкая'
    sent_data_text5 ['name'] = 'На стекле'
    data.append(sent_data_text5)

# %%
with open ('pravilo_imjon.txt', encoding='utf-8') as f6:
    text6 = f6.read()
doc6 = Doc (text6)
doc6.segment(segmenter)
for elem6 in doc6.sents:
    sent_data_text6 = {}
    lemma_tag_data = []
    sent_text = elem6.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text6['sent_text'] = sent_text
    sent_data_text6 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text6 ['link'] = 'https://ficbook.net/readfic/3527947'
    sent_data_text6 ['author'] = 'darketo31'
    sent_data_text6 ['name'] = 'Правило имён'
    data.append(sent_data_text6)

# %%
with open ('u_nego_takie_glaza.txt', encoding='utf-8') as f7:
    text7 = f7.read()
doc7 = Doc (text7)
doc7.segment(segmenter)
for elem7 in doc7.sents:
    sent_data_text7 = {}
    lemma_tag_data = []
    sent_text = elem7.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text7['sent_text'] = sent_text
    sent_data_text7 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text7 ['link'] = 'https://ficbook.net/readfic/3295719'
    sent_data_text7 ['author'] = 'tuuli-veter'
    sent_data_text7 ['name'] = 'У него такие глаза'
    data.append(sent_data_text7)

# %%
with open ('uzhe_ne_sbezhatj.txt', encoding='utf-8') as f8:
    text8 = f8.read()
doc8 = Doc (text8)
doc8.segment(segmenter)
for elem8 in doc8.sents:
    sent_data_text8 = {}
    lemma_tag_data = []
    sent_text = elem8.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text8['sent_text'] = sent_text
    sent_data_text8 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text8 ['link'] = 'https://ficbook.net/readfic/1321793'
    sent_data_text8 ['author'] = 'Leksa Hikari'
    sent_data_text8 ['name'] = 'Уже не сбежать'
    data.append(sent_data_text8)

# %%
with open ('zatknisj.txt', encoding='utf-8') as f9:
    text9 = f9.read()
doc9 = Doc (text9)
doc9.segment(segmenter)
for elem9 in doc9.sents:
    sent_data_text9 = {}
    lemma_tag_data = []
    sent_text = elem9.text
    if '\n' in sent_text:
        sent_text = sent_text.replace ('\n', ' ')
    tokenizer = word_tokenize(sent_text)
    for w in tokenizer:
        if w != None:
            lemm_data = []
            lemm = morph.parse(w)[0].normal_form
            lemm_data.append(lemm)
            pos_data = tag_handler(morph.parse(w)[0].tag.POS)
            if w.isdigit():
                pos_data = 'NUMR'
            lemm_data.append(pos_data)
            lemma_tag_data.append(lemm_data)
    sent_data_text9['sent_text'] = sent_text
    sent_data_text9 ['lemmas_and_tags'] = lemma_tag_data
    sent_data_text9 ['link'] = 'https://ficbook.net/readfic/7339615'
    sent_data_text9 ['author'] = 'tuuli-veter'
    sent_data_text9 ['name'] = 'Заткнись'
    data.append(sent_data_text9)

# %%
df = pd.DataFrame(data)
df
# Out:
#                                               sent_text  \
# 0                                    - Джеймс, пойми...
# 1                                 - Нет! - отрезал муж.
# 2     - Покидать страну в такой сложный момент - не ...
# 3     Мы не можем бросить на произвол судьбы Орден ф...
# 4                                 Как ты не понимаешь?!
# ...                                                 ...
# 2448  Какое-то время он напряжен и загнанно дышит, н...
# 2449                                       — Я. Никуда.
# 2450                                           Не уйду.
# 2451  Обещаю, — шепчет он и, слава Мерлину, затыкается.
# 2452  Потому что нам с ним обоим давно уже пора пере...
#
#                                         lemmas_and_tags  \
# 0     [[-, None], [джеймс, NOUN], [,, None], [понять...
# 1     [[-, None], [нет, PRED], [!, None], [-, None],...
# 2     [[-, None], [покидать, VERB], [страна, NOUN], ...
# 3     [[мы, NPRO], [не, PRCL], [мочь, VERB], [бросит...
# ...

# %%
df.to_csv("data_table.csv", index=None)
